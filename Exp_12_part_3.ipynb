# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshika-g/OS-lab-experiment/blob/main/Exp_12_part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile exp14_linked.c
#
# #include <stdio.h>
#
# int main()
# {
#     int n, blocks[20], i;
#
#     printf("Enter Number of Blocks: ");
#     scanf("%d", &n);
#
#     printf("Enter Block Numbers:\n");
#
#     for(i = 0; i < n; i++)
#     {
#         scanf("%d", &blocks[i]);
#     }
#
#     printf("\nLinked Allocation:\n");
#
#     for(i = 0; i < n - 1; i++)
#     {
#         printf("%d --> ", blocks[i]);
#     }
#
#     printf("%d --> NULL\n", blocks[n - 1]);
#
#     return 0;
# }
# Out:
# Writing exp14_linked.c

# %%
# !gcc exp14_linked.c -o exp14_linked
# !./exp14_linked
# Out:
# Enter Number of Blocks: 3
# Enter Block Numbers:
# 2
# 1
# 4
#
# Linked Allocation:
# 2 --> 1 --> 4 --> NULL
