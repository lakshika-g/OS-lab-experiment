# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshika-g/OS-lab-experiment/blob/main/Exp_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile exp8.c
# #include <stdio.h>
#
# int main()
# {
#     int allocation[10][10], request[10][10];
#     int available[10], work[10];
#     int finish[10];
#     int n, m, i, j, k, found;
#
#     printf("Enter Number of Processes: ");
#     scanf("%d", &n);
#
#     printf("Enter Number of Resource Types: ");
#     scanf("%d", &m);
#
#     printf("\nEnter Allocation Matrix:\n");
#     for(i = 0; i < n; i++)
#         for(j = 0; j < m; j++)
#             scanf("%d", &allocation[i][j]);
#
#     printf("\nEnter Request Matrix:\n");
#     for(i = 0; i < n; i++)
#         for(j = 0; j < m; j++)
#             scanf("%d", &request[i][j]);
#
#     printf("\nEnter Available Resources:\n");
#     for(i = 0; i < m; i++)
#     {
#         scanf("%d", &available[i]);
#         work[i] = available[i];
#     }
#
#     for(i = 0; i < n; i++)
#         finish[i] = 0;
#
#     do
#     {
#         found = 0;
#
#         for(i = 0; i < n; i++)
#         {
#             if(finish[i] == 0)
#             {
#                 for(j = 0; j < m; j++)
#                 {
#                     if(request[i][j] > work[j])
#                         break;
#                 }
#
#                 if(j == m)
#                 {
#                     for(k = 0; k < m; k++)
#                         work[k] += allocation[i][k];
#
#                     finish[i] = 1;
#                     found = 1;
#                 }
#             }
#         }
#
#     } while(found);
#
#     found = 0;
#
#     printf("\nDeadlocked Processes: ");
#
#     for(i = 0; i < n; i++)
#     {
#         if(finish[i] == 0)
#         {
#             printf("P%d ", i);
#             found = 1;
#         }
#     }
#
#     if(found == 0)
#         printf("No Deadlock Detected");
#
#     printf("\n");
#
#     return 0;
# }
# Out:
# Writing exp8.c

# %%
# !gcc exp8.c -o exp8
# !./exp8
# Out:
# Enter Number of Processes: 5
# Enter Number of Resource Types: 3
#
# Enter Allocation Matrix:
# 000
# 001
# 010
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 108
# 109
# 222
# 201
# 223
#
# Enter Request Matrix:
# 222
# 223
# 109
# 108
# 105104
# 103
# 102
# 101
# 100
# 010
# 000
# 001
# 106
# 107
# 108
#
# Enter Available Resources:
# 222
# 108
# 107
#
# Deadlocked Processes: P1
