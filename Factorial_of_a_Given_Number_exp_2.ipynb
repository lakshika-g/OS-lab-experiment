# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshika-g/OS-lab-experiment/blob/main/Factorial_of_a_Given_Number_exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# echo "Calculating factorial for 17:"
# n=17
# fact=1
# while [ $n -gt 1 ]
# do
# fact=$((fact * n))
# n=$((n - 1))
# done
# echo "FACTORIAL IS $fact"
# Out:
# ENTER THE NUMBER:
# FACTORIAL OF THE GIVEN NUMBER IS
# bash: line 2: 17: command not found
# bash: line 6: [: fact=1: integer expression expected
