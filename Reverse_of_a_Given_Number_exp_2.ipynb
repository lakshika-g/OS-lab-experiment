# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshika-g/OS-lab-experiment/blob/main/Reverse_of_a_Given_Number_exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# echo "ENTER THE NUMBER"
# read n
# rnum=0
# while [ $n -ne 0 ]
# do
# remainder=$((n % 10))
# rnum=$((rnum * 10 + remainder))
# n=$((n / 10))
# done
# echo "REVERSE OF THE NUMBER IS $rnum"
# Out:
# ENTER THE NUMBER
# REVERSE OF THE NUMBER IS
# bash: line 4: [: rnum=0: integer expression expected
