# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshika-g/OS-lab-experiment/blob/main/Exp_15_part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile exp15_scan.c
#
# #include <stdio.h>
#
# int main()
# {
#     int disk_size = 200;
#     int head = 53;
#
#     printf("SCAN Disk Scheduling\n");
#     printf("Initial Head Position : %d\n", head);
#     printf("Head moves towards higher cylinders,\n");
#     printf("then reverses direction.\n");
#
#     return 0;
# }
# Out:
# Writing exp15_scan.c

# %%
# !gcc exp15_scan.c -o exp15_scan
# !./exp15_scan
# Out:
# SCAN Disk Scheduling
# Initial Head Position : 53
# Head moves towards higher cylinders,
# then reverses direction.
