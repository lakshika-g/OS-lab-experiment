# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshika-g/OS-lab-experiment/blob/main/Priority_Scheduling_exp_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile priority.c
# #include <stdio.h>
#
# int main()
# {
#     int n, i, j, temp;
#     int bt[20], pr[20], wt[20], tat[20];
#     float avg_wt = 0, avg_tat = 0;
#
#     printf("Enter Number of Processes: ");
#     scanf("%d", &n);
#
#     for(i = 0; i < n; i++)
#     {
#         printf("Enter Burst Time for P%d: ", i + 1);
#         scanf("%d", &bt[i]);
#
#         printf("Enter Priority for P%d: ", i + 1);
#         scanf("%d", &pr[i]);
#     }
#
#     /* Sort according to priority */
#     for(i = 0; i < n - 1; i++)
#     {
#         for(j = i + 1; j < n; j++)
#         {
#             if(pr[i] > pr[j])
#             {
#                 temp = pr[i];
#                 pr[i] = pr[j];
#                 pr[j] = temp;
#
#                 temp = bt[i];
#                 bt[i] = bt[j];
#                 bt[j] = temp;
#             }
#         }
#     }
#
#     wt[0] = 0;
#
#     for(i = 1; i < n; i++)
#         wt[i] = wt[i - 1] + bt[i - 1];
#
#     printf("\nProcess\tPriority\tBT\tWT\tTAT\n");
#
#     for(i = 0; i < n; i++)
#     {
#         tat[i] = wt[i] + bt[i];
#
#         avg_wt += wt[i];
#         avg_tat += tat[i];
#
#         printf("P%d\t%d\t\t%d\t%d\t%d\n",
#                i + 1, pr[i], bt[i], wt[i], tat[i]);
#     }
#
#     avg_wt /= n;
#     avg_tat /= n;
#
#     printf("\nAverage Waiting Time = %.2f", avg_wt);
#     printf("\nAverage Turnaround Time = %.2f\n", avg_tat);
#
#     return 0;
# }
# Out:
# Writing priority.c

# %%
# !gcc priority.c -o priority
# !./priority
# Out:
# Enter Number of Processes: 3
# Enter Burst Time for P1: 5
# Enter Priority for P1: 8
# Enter Burst Time for P2: 4
# Enter Priority for P2: 7
# Enter Burst Time for P3: 8
# Enter Priority for P3: 6
#
# Process	Priority	BT	WT	TAT
# P1	6		8	0	8
# P2	7		4	8	12
# P3	8		5	12	17
#
# Average Waiting Time = 6.67
# Average Turnaround Time = 12.33
